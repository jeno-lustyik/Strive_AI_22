# %%
# Processing the text line by line, putting them into one block of text, then giving it back in alphabetical order, counted.
def word_counter(file):
    fp = open(file)
    text = ""
    list_text = []
    count_dir = {}
    for i in fp.readlines():
        k = "".join(i).replace("\n", " ").lower()
        for char in k:
            if 'a' <= char <= 'z' or 'A' <= char <= 'Z' or char == ' ' or '0' <= char <= '9' or char == "'":
            # if 'a' <= char <= 'z' or 'A' <= char <= 'Z' or char == ' ' or char == "'" or char == '"' or '0' <= char <= '9':
                text += char
    list_text = sorted(text.split())
    for n in list_text:
        if n not in count_dir:
            count_dir[list_text[list_text.index(n)]] = list_text.count(n)
    print(count_dir)
        # for char in "".join(i):
        #     print("".join(i))
        #     if 'a' <= char <= 'z' or 'A' <= char <= 'Z' or char == ' ' or char == "'" or '0' <= char <= '9':
        #         print(char)
        #         text += char
        #         print(text)
    fp.close()
    return

word_counter("blakepoems.txt")
# Out:
# {"'come": 1, "'twas": 1, '1780': 1, '1789': 1, 'a': 127, 'about': 1, 'abroad': 1, 'abstract': 1, 'ache': 1, 'admired': 1, 'adona': 1, 'afar': 1, 'affright': 1, 'after': 2, 'again': 3, 'against': 1, 'age': 2, 'aged': 1, 'agree': 1, 'ah': 7, 'air': 6, 'airy': 1, 'alas': 1, "albion's": 1, 'ale': 1, 'alehouse': 1, 'all': 39, 'allay': 1, 'alone': 1, 'altar': 1, 'always': 1, 'am': 16, 'ambush': 1, 'among': 8, 'an': 21, 'ancient': 3, 'and': 348, 'angel': 8, 'angelguarded': 1, 'angels': 2, 'angry': 2, 'annoy': 1, 'another': 4, "another's": 4, 'answer': 2, 'answerd': 3, 'answered': 2, 'anvil': 1, 'anxious': 1, 'any': 3, 'appall': 1, 'appals': 1, 'apparel': 1, 'appear': 2, 'appeared': 1, 'appears': 1, 'appendix': 1, 'apple': 1, 'are': 25, 'arise': 9, 'arm': 2, 'armed': 4, 'arms': 1, 'arose': 1, 'around': 5, 'arrow': 1, 'arrows': 1, 'art': 6, 'artful': 1, 'as': 16, 'ask': 2, 'asleep': 2, 'asleeping': 1, 'aspire': 2, "astonish'd": 1, 'at': 7, 'author': 1, 'away': 24, 'awoke': 1, 'babe': 2, 'babe
# ...

# %%
# Counting words and adding them to dictionary line by line. TO BE FINALIZED!!
def word_counter(file):
    fp = open(file)
    count_dir = {}
    for i in fp.readlines():
        k = "".join(i).replace("\n", " ").lower()
        text = ""
        for char in k:
            if 'a' <= char <= 'z' or 'A' <= char <= 'Z' or char == ' ' or '0' <= char <= '9' or char == "'":
            # if 'a' <= char <= 'z' or 'A' <= char <= 'Z' or char == ' ' or char == "'" or char == '"' or '0' <= char <= '9':
                text += char
        list_text = sorted(text.split())
        for n in list_text:
            if n not in count_dir:
                count_dir[n] = list_text.count(n)
            else:
                count_dir[n] += list_text.count(n)
    print(count_dir)
        # for char in "".join(i):
        #     print("".join(i))
        #     if 'a' <= char <= 'z' or 'A' <= char <= 'Z' or char == ' ' or char == "'" or '0' <= char <= '9':
        #         print(char)
        #         text += char
        #         print(text)
    fp.close()
    return

word_counter("blakepoems.txt")
# Out:
# {'1789': 1, 'blake': 3, 'by': 26, 'poems': 1, 'william': 2, 'can': 27, 'do': 9, 'this': 16, 'you': 10, 'and': 448, 'experience': 3, 'innocence': 3, 'of': 172, 'songs': 7, 'book': 6, 'the': 577, 'thel': 15, 'introduction': 2, 'down': 20, 'piping': 3, 'valleys': 4, 'wild': 9, 'glee': 1, 'pleasant': 5, 'a': 147, 'child': 18, 'cloud': 15, 'i': 151, 'on': 50, 'saw': 7, 'he': 56, 'laughing': 5, 'me': 36, 'said': 8, 'to': 129, 'about': 1, 'lamb': 14, 'pipe': 6, 'song': 10, 'cheer': 2, 'merry': 11, 'piped': 2, 'so': 21, 'with': 66, 'again': 3, 'piper': 2, 'that': 41, 'hear': 16, 'wept': 9, 'drop': 1, 'happy': 19, 'thy': 37, 'sing': 11, 'same': 1, 'sang': 2, 'joy': 25, 'while': 14, 'sit': 12, 'thee': 46, 'write': 1, 'all': 39, 'in': 155, 'may': 6, 'read': 2, 'from': 34, 'my': 97, 'sight': 2, "vanish'd": 1, 'hollow': 3, "pluck'd": 1, 'reed': 1, 'made': 6, 'pen': 1, 'rural': 1, 'clear': 1, "stain'd": 1, 'water': 3, 'wrote': 1, 'every': 23, 'shepherd': 2, 'how': 16, 'is': 56, 'lot': 2, "shepherd
# ...
