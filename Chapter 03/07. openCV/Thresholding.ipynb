# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('hsv.png')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 6>()
#       3 import numpy as np
#       5 img = cv.imread('hsv.png')
# ----> 6 plt.imshow(img)
#
# File ~\anaconda3\envs\openCV\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# ...
