# %%
import cv2
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
img = cv2.imread('Attributes-Elden-Ring-Classes-Leak.jpg')
img2 = cv2.imread('doge_ranni.jpg')

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
plt.figure(figsize=(20, 15))
plt.imshow(img)

# %%
rgb_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20, 15))
plt.imshow(rgb_img)
